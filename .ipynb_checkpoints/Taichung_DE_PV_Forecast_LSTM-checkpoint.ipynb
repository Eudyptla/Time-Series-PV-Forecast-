# %% [markdown]
# ## Taichung DE forecast by LSTM
#
# Data source :  TaiChung DE PV plant, CWB WUQI weather.
#
# Time period : 2016/01/01-2017/12/31.
#
# Time frequcy: 1 hour.
#
# Try LSTM to forecast.

# %%
# import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.callbacks import EarlyStopping

# %% [markdown]
# # Data processing
#
# Visualizing data.

# %%
# quick look data
data = pd.read_csv('data\\Taichung_Power_Weather.csv', parse_dates=['Date'], index_col='Date')
# visualizing data
data.plot(subplots=True, linewidth=0.5, layout=(8, 2), figsize=(12, 16),
          sharex=False, sharey=False)
plt.show()

# %% [markdown]
# power(KWH)_replaced : PV plant produce energy ($KWH$).
#
# StnPres : station pressure ($hPa$).
#
# SeaPres :  sea surface pressure ($hPa$).
#
# Temperature : temperature ($^{\circ}C$).
#
# Td dew point : dew point temperature($^{\circ}C$).
#
# RH : relative humidity ($\%$).
#
# WS :  wind speed($m/s$).
#
# WD :  wind direction ($^{\circ}$).
#
# WSGust :   the maximum gust wind speed($m/s$).
#
# WDGust :   the maximum gust wind direction ($^{\circ}$).
#
# Precp : precipitation ($mm$).
#
# PrecpHour : precipitation duration($Hour$).
#
# SunShine : sunshine duration($Hour$).
#
# GlobRad : global radiation($MJ/m^{2}$).
#
# Solar Irradiance : solar irradiance ($KJ/m^{2}$)

# %% [markdown]
# Contain outlier, replace.
#
# Let data in  $mean - 3 \times std < data < mean + 3 \times std $ .
#
# Don't care night , choose day time .

# %%
# replace outlier
def replace_outlier(series):
    series_mean = series.mean()
    series_std = series.std()
    upper = series_mean + 3 * series_std 
    lower = series_mean - 3 * series_std
    series_new = np.where(series > upper, upper, np.where(series < lower, lower, series))
    return series_new
# choose day time
daytime_idx = ((6<= data.index.hour) & (data.index.hour<= 18))

for col in data.columns:
    data.loc[daytime_idx,col] = replace_outlier(data.loc[daytime_idx,col])

print(data[daytime_idx].describe().transpose())
# Out:
#                       count         mean         std         min         25%  \
# power(KWH)_replaced  9503.0   386.390656  349.470772    0.000000    56.00000
# StnPres              9503.0  1010.017104    5.922215  991.783876  1005.90000
# SeaPres              9503.0  1013.114979    5.992838  994.676048  1009.00000
# Temperature          9503.0    24.368349    5.722668    7.162121    19.70000
# Td dew point         9503.0    19.659760    5.599656    2.742113    15.40000
# RH                   9503.0    75.614142    9.091097   47.962242    70.00000
# WS                   9503.0     5.052438    2.775342    0.000000     3.00000
# WD                   9503.0   255.102073  119.531531    0.000000   170.00000
# WSGust               9503.0    10.006392    5.374613    1.100000     6.00000
# WDGust               9503.0   220.930233  131.512571   10.000000   110.00000
# Precp                9503.0     0.107764    0.533163    0.000000     0.00000
# PrecpHour            9503.0     0.042590    0.154661    0.000000     0.00000
# SunShine             9503.0     0.435357    0.440169    0.000000     0.00000
# GloblRad             9503.0     1.201591    1.082599    0.000000     0.19000
# Solar Irradiance     9503.0   292.192119  256.986338    0.000000    60.01763
#
#                              50%          75%          max
# power(KWH)_replaced   300.000000   682.000000  1435.202172
# StnPres              1009.500000  1014.300000  1028.193963
# SeaPres              1012.600000  1017.400000  1031.498844
# Temperature            25.400000    29.500000    34.700000
# Td dew point           21.200000    24.600000    27.500000
# RH                     76.000000    82.000000   100.000000
# WS                      4.700000     6.800000    13.562070
# WD                    320.000000   350.000000   360.000000
# WSGust                  8.800000    13.400000    26.473328
# WDGust                260.000000   350.000000   360.000000
# Precp                   0.000000     0.000000     4.142196
# PrecpHour               0.000000     0.000000     0.673098
# SunShine                0.300000     1.000000     1.000000
# GloblRad                0.940000     2.010000     3.840000
# Solar Irradiance      223.679079   498.403219   909.122505

# %% [markdown]
# Drop WS, WD, WDGust and WDGust because this is PV forecast.
#
# Drop Precp and PrecpHour ,because 75% data are zero.

# %%
data_drop = data[daytime_idx].drop(columns=['WS', 'WD', 'WSGust', 'WDGust', 'Precp', 'PrecpHour'])

# %% [markdown]
# # One encoding
#
# Generate morning, afternoon and night.

# %%
data_drop['Hour'] = data_drop.index.hour 
def time_period(hour):
    if 6 <= hour <= 12:
        return 'morning'
    else:
        return 'afternoon'
data_drop['period'] = data_drop['Hour'].apply(time_period)
data_drop = data_drop.join(pd.get_dummies(data_drop['period']))
data_drop.drop(columns=['period'], inplace=True)
print(data_drop.head(3))
# Out:
#                      power(KWH)_replaced  StnPres  SeaPres  Temperature  \
# Date
# 2016-01-01 06:00:00                  0.0   1021.4   1024.6         14.8
# 2016-01-01 07:00:00                  0.0   1022.1   1025.3         14.6
# 2016-01-01 08:00:00                146.0   1022.7   1025.9         15.8
#
#                      Td dew point    RH  SunShine  GloblRad  Solar Irradiance  \
# Date
# 2016-01-01 06:00:00          11.3  80.0       0.0       0.0          4.164694
# 2016-01-01 07:00:00          11.4  81.0       0.0       0.0        107.933226
# 2016-01-01 08:00:00          12.1  79.0       0.7       0.3        305.363132
#
#                      Hour  afternoon  morning
# Date
# 2016-01-01 06:00:00     6          0        1
# 2016-01-01 07:00:00     7          0        1
# 2016-01-01 08:00:00     8          0        1

# %% [markdown]
# Norm min =0, max =1.

# %%
X_scale = MinMaxScaler(feature_range=(0, 1))
y_scale = MinMaxScaler(feature_range=(0, 1))
X_norm = X_scale.fit_transform(data_drop.iloc[:,1:])
y_norm = y_scale.fit_transform(data_drop.iloc[:,[0]])

# %%
data_scaled_X = pd.DataFrame(X_norm, index=data_drop.index, columns=data_drop.columns[1:])
data_scaled_y = pd.DataFrame(y_norm, index=data_drop.index, columns=[data_drop.columns[0]])
data_scaled = data_scaled_X.join(data_scaled_y)
data_scaled.head(3)
# Out:
#                       StnPres   SeaPres  Temperature  Td dew point        RH  \
# Date
# 2016-01-01 06:00:00  0.813404  0.812647     0.277359      0.345663  0.615664
# 2016-01-01 07:00:00  0.832630  0.831657     0.270096      0.349702  0.634881
# 2016-01-01 08:00:00  0.849109  0.847952     0.313673      0.377976  0.596447
#
#                      SunShine  GloblRad  Solar Irradiance      Hour  \
# Date
# 2016-01-01 06:00:00       0.0  0.000000          0.004581  0.000000
# 2016-01-01 07:00:00       0.0  0.000000          0.118722  0.083333
# 2016-01-01 08:00:00       0.7  0.078125          0.335888  0.166667
#
#                      afternoon  morning  power(KWH)_replaced
# Date
# 2016-01-01 06:00:00        0.0      1.0             0.000000
# 2016-01-01 07:00:00        0.0      1.0             0.000000
# 2016-01-01 08:00:00        0.0      1.0             0.101728

# %%
# Creating time-lagged features
def create_lags(df, col ,N):
    for i in N:
        for j in col:
            df[j+'_Lag_' + str(i)] = df[j].shift(i)
    return df

data_lag=create_lags(data_scaled.copy(), data_scaled.columns,[1,13])

data_lag.dropna(inplace=True)
print(data_lag.head(3))
# Out:
#                       StnPres   SeaPres  Temperature  Td dew point        RH  \
# Date
# 2016-01-02 06:00:00  0.758475  0.758333     0.386300      0.511267  0.730965
# 2016-01-02 07:00:00  0.780446  0.780059     0.386300      0.495110  0.692531
# 2016-01-02 08:00:00  0.785939  0.785490     0.408088      0.507228  0.654097
#
#                      SunShine  GloblRad  Solar Irradiance      Hour  \
# Date
# 2016-01-02 06:00:00       0.0  0.000000          0.003325  0.000000
# 2016-01-02 07:00:00       0.0  0.000000          0.058134  0.083333
# 2016-01-02 08:00:00       0.1  0.020833          0.238955  0.166667
#
#                      afternoon  ...  Temperature_Lag_13  Td dew point_Lag_13  \
# Date                            ...
# 2016-01-02 06:00:00        0.0  ...            0.277359             0.345663
# 2016-01-02 07:00:00        0.0  ...            0.270096             0.349702
# 2016-01-02 08:00:00        0.0  ...            0.313673             0.377976
#
#                      RH_Lag_13  SunShine_Lag_13  GloblRad_Lag_13  \
# Date
# 2016-01-02 06:00:00   0.615664              0.0         0.000000
# 2016-01-02 07:00:00   0.634881              0.0         0.000000
# 2016-01-02 08:00:00   0.596447              0.7         0.078125
#
#                      Solar Irradiance_Lag_13  Hour_Lag_13  afternoon_Lag_13  \
# Date
# 2016-01-02 06:00:00                 0.004581     0.000000               0.0
# 2016-01-02 07:00:00                 0.118722     0.083333               0.0
# 2016-01-02 08:00:00                 0.335888     0.166667               0.0
#
#                      morning_Lag_13  power(KWH)_replaced_Lag_13
# Date
# 2016-01-02 06:00:00             1.0                    0.000000
# 2016-01-02 07:00:00             1.0                    0.000000
# 2016-01-02 08:00:00             1.0                    0.101728
#
# [3 rows x 36 columns]

# %% [markdown]
# Choose target and feature.

# %%
Feature_lag24 = data_lag.iloc[:,-data_scaled.shape[1]:]
Feature_lag1 = data_lag.iloc[:,-2*data_scaled.shape[1]:-data_scaled.shape[1]]
Target = data_lag['power(KWH)_replaced']
Feature = np.stack([Feature_lag1,Feature_lag24],axis=2)

# %% [markdown]
# Split train test datasets.

# %%
# split train test data
X_train, X_test, y_train, y_test = train_test_split(Feature, Target, test_size=0.166,shuffle=False)

# %%
def buildManyToOneModel(shape):

    model = Sequential()
    model.add(LSTM(64, input_shape=(shape[1],shape[2],), activation='relu', return_sequences=True))
    model.add(LSTM(16, activation='relu', return_sequences=False))
    model.add(Dense(1))
    model.compile(loss="mean_squared_error", optimizer="adam"
                ,metrics=['mean_squared_error'])
    return model

model = buildManyToOneModel(X_train.shape)
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 12, 64)            17152
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 16)                5184
# _________________________________________________________________
# dense (Dense)                (None, 1)                 17
# =================================================================
# Total params: 22,353
# Trainable params: 22,353
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
callback = EarlyStopping(monitor="val_loss", patience=10, verbose=1, mode="auto")
history = model.fit(X_train, y_train, epochs=1000, batch_size=128, verbose=2, validation_data=(X_test, y_test), callbacks=[callback])
# Out:
# Epoch 1/1000
# 62/62 - 3s - loss: 0.0471 - mean_squared_error: 0.0471 - val_loss: 0.0256 - val_mean_squared_error: 0.0256
# Epoch 2/1000
# 62/62 - 1s - loss: 0.0188 - mean_squared_error: 0.0188 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 3/1000
# 62/62 - 1s - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0086 - val_mean_squared_error: 0.0086
# Epoch 4/1000
# 62/62 - 1s - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0086 - val_mean_squared_error: 0.0086
# Epoch 5/1000
# 62/62 - 1s - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0082 - val_mean_squared_error: 0.0082
# Epoch 6/1000
# 62/62 - 1s - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0076 - val_mean_squared_error: 0.0076
# Epoch 7/1000
# 62/62 - 1s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 8/1000
# 62/62 - 1s - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 9/1000
# 62/62 - 1s - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 10/1000
# 62/62 - 1s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 11/1000
# 62/62 - 1s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 12/1000
# 62/62 - 1s - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 13/1000
# 62/62 - 1s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 14/1000
# 62/62 - 1s - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 15/1000
# 62/62 - 1s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 16/1000
# 62/62 - 1s - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 17/1000
# 62/62 - 1s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 18/1000
# 62/62 - 1s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 19/1000
# 62/62 - 1s - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 20/1000
# 62/62 - 1s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 21/1000
# 62/62 - 1s - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 22/1000
# 62/62 - 1s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 23/1000
# 62/62 - 1s - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 24/1000
# 62/62 - 1s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 25/1000
# 62/62 - 1s - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 26/1000
# 62/62 - 1s - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 27/1000
# 62/62 - 1s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 28/1000
# 62/62 - 1s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 29/1000
# 62/62 - 1s - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 30/1000
# 62/62 - 1s - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 31/1000
# 62/62 - 1s - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 32/1000
# 62/62 - 1s - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 33/1000
# 62/62 - 1s - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 34/1000
# 62/62 - 1s - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 35/1000
# 62/62 - 1s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 36/1000
# 62/62 - 1s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 37/1000
# 62/62 - 1s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 38/1000
# 62/62 - 1s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 39/1000
# 62/62 - 1s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 40/1000
# 62/62 - 1s - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 41/1000
# 62/62 - 1s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 42/1000
# 62/62 - 1s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 43/1000
# 62/62 - 1s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 44/1000
# 62/62 - 1s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 45/1000
# 62/62 - 1s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 46/1000
# 62/62 - 1s - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 47/1000
# 62/62 - 1s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 48/1000
# 62/62 - 1s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 49/1000
# 62/62 - 1s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 50/1000
# 62/62 - 1s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 51/1000
# 62/62 - 1s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 52/1000
# 62/62 - 1s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 53/1000
# 62/62 - 1s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 54/1000
# 62/62 - 1s - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 55/1000
# 62/62 - 1s - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 56/1000
# 62/62 - 1s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 57/1000
# 62/62 - 1s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 58/1000
# 62/62 - 1s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 59/1000
# 62/62 - 1s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 60/1000
# 62/62 - 1s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 61/1000
# 62/62 - 1s - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 62/1000
# 62/62 - 1s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 63/1000
# 62/62 - 1s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 64/1000
# 62/62 - 1s - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 65/1000
# 62/62 - 1s - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 66/1000
# 62/62 - 1s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 67/1000
# 62/62 - 1s - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 68/1000
# 62/62 - 1s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 69/1000
# 62/62 - 1s - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 70/1000
# 62/62 - 1s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 71/1000
# 62/62 - 1s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 72/1000
# 62/62 - 1s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 73/1000
# 62/62 - 1s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 74/1000
# 62/62 - 1s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 75/1000
# 62/62 - 1s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 76/1000
# 62/62 - 1s - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 77/1000
# 62/62 - 1s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 78/1000
# 62/62 - 1s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 79/1000
# 62/62 - 1s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 80/1000
# 62/62 - 1s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 81/1000
# 62/62 - 1s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 82/1000
# 62/62 - 1s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 83/1000
# 62/62 - 1s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 84/1000
# 62/62 - 1s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 85/1000
# 62/62 - 1s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 86/1000
# 62/62 - 1s - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 87/1000
# 62/62 - 1s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 88/1000
# 62/62 - 1s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 89/1000
# 62/62 - 1s - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 90/1000
# 62/62 - 1s - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 91/1000
# 62/62 - 1s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 92/1000
# 62/62 - 1s - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 93/1000
# 62/62 - 1s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 94/1000
# 62/62 - 1s - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 95/1000
# 62/62 - 1s - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 96/1000
# 62/62 - 1s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 97/1000
# 62/62 - 1s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 98/1000
# 62/62 - 1s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 99/1000
# 62/62 - 1s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 100/1000
# 62/62 - 1s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 101/1000
# 62/62 - 1s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 102/1000
# 62/62 - 1s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 103/1000
# 62/62 - 1s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 104/1000
# 62/62 - 1s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 105/1000
# 62/62 - 1s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 106/1000
# 62/62 - 1s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 107/1000
# 62/62 - 1s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 108/1000
# 62/62 - 1s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 109/1000
# 62/62 - 1s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 110/1000
# 62/62 - 1s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 111/1000
# 62/62 - 1s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 112/1000
# 62/62 - 1s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 113/1000
# 62/62 - 1s - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 114/1000
# 62/62 - 1s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 115/1000
# 62/62 - 1s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 116/1000
# 62/62 - 1s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 117/1000
# 62/62 - 1s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 118/1000
# 62/62 - 1s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 119/1000
# 62/62 - 1s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 120/1000
# 62/62 - 1s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 121/1000
# 62/62 - 1s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 122/1000
# 62/62 - 1s - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 123/1000
# 62/62 - 1s - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 124/1000
# 62/62 - 1s - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 125/1000
# 62/62 - 2s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 126/1000
# 62/62 - 1s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 127/1000
# 62/62 - 1s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 128/1000
# 62/62 - 1s - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 00128: early stopping

# %%
def plot_history(history):
    hist = pd.DataFrame(history.history)
    hist['epoch'] = history.epoch
    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('Mean Square Error')
    plt.plot(hist['epoch'], hist['mean_squared_error'],
             label='Train Error')
    plt.plot(hist['epoch'], hist['val_mean_squared_error'],
             label='Val Error')
    plt.legend()

# The patience parameter is the amount of epochs to check for improvement

plot_history(history)

# %%
y_test_value = y_scale.inverse_transform(y_test.values.reshape(-1, 1))
y_predict_norm = model.predict(X_test)
y_predict = y_scale.inverse_transform(y_predict_norm)

# %%
# visualizing predict
fig, ax = plt.subplots(figsize=(18,12))
ax.plot(y_test.index, y_test_value, color='k', alpha=.3, lw=3)
ax.plot(y_test.index, y_predict)
ax.set(xlabel="Time")
plt.show()

# %%
def MRE(x,y):
    return np.nanmean(np.abs((x-y)/np.max(x)))

print('Mean squared error:{:.4f}'.format(mean_squared_error(y_test_value, y_predict)))
print('Mean absolute error:{:.4f}'.format(mean_absolute_error(y_test_value,y_predict)))
print('Mean relative error:{:.2%}'.format(MRE(y_test_value, y_predict)))
print('Coefficient of determination:{:.4f}'.format(r2_score(y_test_value, y_predict)))
# Out:
# Mean squared error:9180.2606
# Mean absolute error:51.1283
# Mean relative error:3.56%
# Coefficient of determination:0.9261
