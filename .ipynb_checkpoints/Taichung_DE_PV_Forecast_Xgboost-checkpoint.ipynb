# %% [markdown]
# # Taichung DE Forecast  with Xgboost
#
# Data source : TaiChung DE PV plant, CWB WUQI weather.
#
# Time period : 2016/01/01-2017/12/31.
#
# Time frequcy: 1 hour.

# %%
# import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import TimeSeriesSplit, RandomizedSearchCV
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import xgboost as xgb
from warnings import filterwarnings
filterwarnings('ignore')
plt.style.use('fivethirtyeight')

# %% [markdown]
# # Visualizing Data

# %%
# quick look data
data = pd.read_csv('data\\Taichung_Power_Weather_R.csv', parse_dates=['Date'], index_col='Date')
# visualizing data
data.plot(subplots=True, linewidth=0.5, layout=(5, 2), figsize=(12, 16),
          sharex=False, sharey=False)
plt.show()

# %% [markdown]
# power(KWH)_replaced : PV plant produce energy ( 𝐾𝑊𝐻 ).
#
# StnPres : station pressure ( ℎ𝑃𝑎 ).
#
# SeaPres : sea surface pressure ( ℎ𝑃𝑎 ).
#
# Temperature : temperature ( ∘𝐶 ).
#
# Td dew point : dew point temperature( ∘𝐶 ).
#
# RH : relative humidity ( % ).
#
# SunShine : sunshine duration( 𝐻𝑜𝑢𝑟 ).
#
# GlobRad : global radiation( 𝑀𝐽/𝑚2 ).
#
# Solar Irradiance : solar irradiance ( 𝐾𝐽/𝑚2 )

# %% [markdown]
# # Generating Features
#
# Generating time lag.
#
# According to SARIMA analysis result: choose time lag 1, 24.

# %%
# Creating time-lagged features
def create_lags(df, col ,N):
    for i in N:
        df[col+'_Lag_' + str(i)] = df[col].shift(i)
    return df

for col in data.columns:
    data_lag=create_lags(data, col,[1,24])

data_lag.dropna(inplace=True)

# %% [markdown]
# Choose day time.
#
# Generating time feature.

# %%
# choose day time
daytime_idx = (6<= data_lag.index.hour) & (data_lag.index.hour<= 18)
data_daytime = data_lag[daytime_idx]

# %%
# generate time feature
data_daytime.loc[:,'Hour'] = data_daytime.index.hour
data_daytime.loc[:,'day_of_year'] = data_daytime.index.dayofyear

# %% [markdown]
# generate morning and afternoon.

# %%
# One of N encoding.
def morning_afternoon(hour):
    if 6<= hour <=12:
        return 'morning'
    else:
        return 'afternoon'

data_daytime['period'] = data_daytime['Hour'].apply(morning_afternoon)
data_daytime = data_daytime.join(pd.get_dummies(data_daytime['period']))
data_daytime.drop(columns=['period'], inplace=True)
print(data_daytime.head(1))
# Out:
#                      power(KWH)_replaced  StnPres  SeaPres  Temperature  \
# Date
# 2016-01-02 06:00:00                  0.0   1019.4   1022.6         17.8
#
#                      Td dew point    RH  SunShine  GloblRad  Solar Irradiance  \
# Date
# 2016-01-02 06:00:00          15.4  86.0       0.0       0.0          3.023185
#
#                      power(KWH)_replaced_Lag_1  ...  SunShine_Lag_1  \
# Date                                            ...
# 2016-01-02 06:00:00                        0.0  ...             0.0
#
#                      SunShine_Lag_24  GloblRad_Lag_1  GloblRad_Lag_24  \
# Date
# 2016-01-02 06:00:00              0.0             0.0              0.0
#
#                      Solar Irradiance_Lag_1  Solar Irradiance_Lag_24  Hour  \
# Date
# 2016-01-02 06:00:00                     0.0                 4.164694     6
#
#                      day_of_year  afternoon  morning
# Date
# 2016-01-02 06:00:00            2          0        1
#
# [1 rows x 31 columns]

# %% [markdown]
# Choosing features and targets.

# %%
Feature = data_daytime.loc[:, 'power(KWH)_replaced_Lag_1':]
Target = data_daytime.loc[:, 'power(KWH)_replaced']

# %% [markdown]
# # Split train and test data.
#
# choose last 4 month to validation model.

# %%
# Split train and test data
X_train, X_test, y_train, y_test = Feature[:'2017-08-31'], Feature['2017-09-01':], Target[:'2017-08-31'], Target['2017-09-01':]

# %% [markdown]
# # Tune Parameters
# Time series can't use cross validtion.
#
# You can't use future data to predict past.

# %%
cv = TimeSeriesSplit(n_splits=5)
fig, ax = plt.subplots(figsize=(10, 5))
for ii, (tr, tt) in enumerate(cv.split(X_train, y_train)):
# Plot training and validation indices
    l1 = ax.scatter(tr, [ii] * len(tr), c=[plt.cm.coolwarm(.1)], marker='_', lw=6)
    l2 = ax.scatter(tt, [ii] * len(tt), c=[plt.cm.coolwarm(.9)], marker='_', lw=6)
    ax.set(ylim=[5,-1],title='TimeSeriesSplit behavior', xlabel='data index', ylabel='CV iteration')
    ax.legend([l1, l2], ['Training','Validation'])

# %%
gbm = xgb.XGBRegressor()
gbm_param_grid = {
    'xgb_model__subsample': np.arange(.5, 1, .05),
    'xgb_model__max_depth': np.arange(3, 16, 1),
    'xgb_model__colsample_bytree': np.arange(.5, 1, .05)}
randomized_neg_mse = RandomizedSearchCV(estimator=gbm,
    param_distributions=gbm_param_grid, n_iter=10,
    scoring='neg_mean_squared_error', cv=TimeSeriesSplit(n_splits=5))
randomized_neg_mse.fit(X_train, y_train)
# Out:
# [15:04:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "xgb_model__colsample_bytree", "xgb_model__max_depth", "xgb_model__subsample" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:04:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "xgb_model__colsample_bytree", "xgb_model__max_depth", "xgb_model__subsample" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# ...

# %%
print("Best mse: ", np.abs(randomized_neg_mse.best_score_))
print("Best model: ", randomized_neg_mse.best_estimator_)
# Out:
# Best mse:  5937.820255521243
# Best model:  XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None,
#              xgb_model__colsample_bytree=0.5, xgb_model__max_depth=15,
#              xgb_model__subsample=0.8500000000000003)

# %%
preds=randomized_neg_mse.predict(X_test)

# %% [markdown]
# # Visualizing result

# %%
# visualizing predict
fig, ax = plt.subplots(figsize=(18,12))
ax.plot(y_test, color='k', alpha=.3, lw=3)
ax.plot(y_test.index, preds)
ax.set(xlabel="Time")
plt.show()

# %% [markdown]
# Model Score
#
# predict value : $ \hat{y}$
#
# actual value : $y$
#
# max of y : $y_{max}$
#
# Mean squared error :
#
# $$ \frac{1}{n} \sum_{k=1}^n ({y_{k} -\hat{y_{k}}})^2 $$
#
# Mean absoluate error :
#
# $$ \frac{1}{n} \sum_{k=1}^n \vert {y_{k} -\hat{y_{k}}} \vert $$
#
# Mean relative error :
#
# $$ \frac{100\%}{n} \sum_{k=1}^n \frac{{y_{k} -\hat{y_{k}}}}{y_{max}}  $$
#
# Coefficient of determination :
#
# $$ R^{2} \equiv 1 - \frac {SS_{res}}{SS_{tot}}$$
#
# $$SS_{res} = \sum_{k=1}^n  { (\hat{y_{k}} - \tilde {y})^2}   ,SS_{tot} = \sum_{k=1}^n  { ({y_{k}} - \tilde {y})^2}
# , \tilde {y} = \frac{1}{n} \sum_{k=1}^n {y_{k}} $$
#
# <!-- Mean absoluate percentage error :
#
# % $$ \frac{100\%}{n} \sum_{k=1}^n \vert \frac{{y_{k} -\hat{y_{k}}}}{y_{k}} \vert $$ -->

# %%
# Compute and print the reslut
def MRE(x,y):
    return np.nanmean(np.abs((x-y)/np.max(x)))

def print_results(y_test, y_predict):
    print('Mean squared error:{:.4f}'.format(mean_squared_error(y_test,y_predict)))
    print('Mean absolute error:{:.4f}'.format(mean_absolute_error(y_test,y_predict)))
    print('Mean relative error:{:.2%}'.format(MRE(y_test,y_predict)))
    print('Coefficient of determination:{:.4f}'.format(r2_score(y_test,y_predict)))

print_results(y_test, preds)
# Out:
# Mean squared error:9107.4860
# Mean absolute error:43.7597
# Mean relative error:3.05%
# Coefficient of determination:0.9265

# %% [markdown]
# # Look at Worst and Best Predicted Days

# %%
test_days = pd.DataFrame(y_test)
test_days['Predicted'] = preds 
test_days['error'] = test_days['power(KWH)_replaced'] - test_days['Predicted']
test_days['abs_error'] = test_days['error'].apply(np.abs)
test_days['year']=test_days.index.year
test_days['month']=test_days.index.month
test_days['day']=test_days.index.day

error_by_day = test_days.groupby(['year','month','day']).mean()[['power(KWH)_replaced','Predicted','error','abs_error']]

# %% [markdown]
# Looking worst predicted ten days.

# %%
# Worst absolute predicted days
worst_ten = error_by_day.sort_values('abs_error', ascending=False).head(10)
worst_date = worst_ten.index[0]
worst_date = str(worst_date[0])+'-'+str(worst_date[1])+'-'+str(worst_date[2])
print(worst_ten)
# Out:
#                 power(KWH)_replaced   Predicted       error   abs_error
# year month day
# 2017 9     5             518.615385  321.568359  197.047032  203.703793
#      11    18            154.307692  309.910828 -155.603147  159.863696
#      9     7             378.384615  398.739929  -20.355329  157.622880
#      10    18            355.076923  334.763855   20.313078  152.415239
#      9     4             616.630936  514.918030  101.712932  144.844158
#      10    11            384.307692  393.524841   -9.217157  144.097779
#      11    20            347.538462  284.518372   63.020101  128.995600
#      10    17            449.461538  373.908569   75.552984  127.438036
#      9     12            460.538462  436.943268   23.595184  115.158226
#            8             328.615385  398.789673  -70.174277  113.006765

# %% [markdown]
# Looking best predicted ten days.

# %%
# Best predicted days
best_ten = error_by_day.sort_values('abs_error', ascending=True).head(10)
best_date = best_ten.index[0]
best_date = str(best_date[0])+'-'+str(best_date[1])+'-'+str(best_date[2])
print(best_ten)
# Out:
#                 power(KWH)_replaced   Predicted     error  abs_error
# year month day
# 2017 12    16             42.000000   40.295963  1.704036   3.711941
#      11    11            157.000000  156.336624  0.663383   5.028984
#            9             467.307692  467.303894  0.003801   5.800137
#            13            144.615385  144.422577  0.192809   6.173282
#            12            181.461538  175.937698  5.523839   6.431808
#      12    2             241.076923  236.435791  4.641134   6.479964
#      11    30            169.846154  163.738449  6.107706   7.951383
#            26            237.538462  234.049606  3.488860   8.114248
#            23            470.923077  468.214111  2.708969   8.980249
#            14            412.769231  404.555908  8.213331   9.671789

# %% [markdown]
# # Plotting best/worst predicted days
# Plotting worst predicted day.

# %%
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(10)
_ = test_days[['power(KWH)_replaced','Predicted']].plot(ax=ax, style=['-','.'])
ax.set_ylim(0, 1250)
ax.set_xbound(lower=worst_date+' 06:00', upper=worst_date +' 18:00')
plot = plt.suptitle(worst_date+ ' - Worst Predicted Day ')

# %% [markdown]
# Plotting best predicted day.

# %%
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(10)
_ = test_days[['power(KWH)_replaced','Predicted']].plot(ax=ax,
                                              style=['-','.'])
ax.set_ylim(0, 1250)
ax.set_xbound(lower=best_date+' 06:00', upper=best_date+' 18:00')
plot = plt.suptitle(best_date+' - Best Predicted Day')
